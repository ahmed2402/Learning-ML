# %% [markdown]
# # Feature Encoding
#
# Feature encoding is the process of transforming `categorical features` into `numeric features`. This is necessary because machine learning algorithms can only handle numeric features. There are many different ways to encode categorical features, and each method has its own advantages and disadvantages. In this notebook, we will explore some of the most popular methods for encoding categorical features, such as:
#
# 1. Label encoding
# 2. Ordinal encoding
# 3. One-hot encoding
# 4. Binary encoding
# 5. Manual Encoding

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data load
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
# # 1. Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['time_encoded'] = le.fit_transform(df['time'])
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  time_encoded
# 0       16.99  1.01  Female     No  Sun  Dinner     2             0
# 1       10.34  1.66    Male     No  Sun  Dinner     3             0
# 2       21.01  3.50    Male     No  Sun  Dinner     3             0
# 3       23.68  3.31    Male     No  Sun  Dinner     2             0
# 4       24.59  3.61  Female     No  Sun  Dinner     4             0

# %% [markdown]
# # 2. Ordinal Encoding

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

oe = OrdinalEncoder(categories=[['Thur', 'Fri', 'Sat', 'Sun']]) #order 
df['encoded_days'] = oe.fit_transform(df[['day']])
df['encoded_days'].value_counts()
# Out:
# encoded_days
# 2.0    87
# 3.0    76
# 0.0    62
# 1.0    19
# Name: count, dtype: int64

# %% [markdown]
# # 3. One hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder
# OneHotEncoder is used to convert categorical variables into a one-hot numeric array.
# The parameter sparse_output=False returns a dense numpy array instead of a sparse matrix.
ohe = OneHotEncoder(sparse_output=False)

# %%
sex_ohe = ohe.fit_transform(df[['sex']])
df[['Female', 'Male']] = sex_ohe
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  Female  Male
# 0       16.99  1.01  Female     No  Sun  Dinner     2     1.0   0.0
# 1       10.34  1.66    Male     No  Sun  Dinner     3     0.0   1.0
# 2       21.01  3.50    Male     No  Sun  Dinner     3     0.0   1.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2     0.0   1.0
# 4       24.59  3.61  Female     No  Sun  Dinner     4     1.0   0.0

# %%
titanic = sns.load_dataset('titanic')
titanic.dropna(subset=['embarked'], inplace=True)  # Drop rows with NaN in 'embarked'
titanic['embarked'].value_counts()
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ohe = OneHotEncoder(sparse_output=False)
embarked_ohe = ohe.fit_transform(titanic[['embarked']])
titanic[['C', 'Q', 'S']] = embarked_ohe
titanic[['C', 'Q', 'S']].value_counts()
# Out:
# C    Q    S
# 0.0  0.0  1.0    644
# 1.0  0.0  0.0    168
# 0.0  1.0  0.0     77
# Name: count, dtype: int64

# %% [markdown]
# # 4. Binary Encoding

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\zainab\anaconda3\lib\site-packages (2.8.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\zainab\anaconda3\lib\site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\zainab\anaconda3\lib\site-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\zainab\anaconda3\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\zainab\anaconda3\lib\site-packages (from category_encoders) (1.7.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\zainab\anaconda3\lib\site-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\zainab\anaconda3\lib\site-packages (from category_encoders) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zainab\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zainab\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zainab\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in c:\users\zainab\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\zainab\anaconda3\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\zainab\anaconda3\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\zainab\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (24.1)

# %%
import category_encoders

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
from category_encoders import BinaryEncoder

binary_encoder = BinaryEncoder()
encoded_smoker = binary_encoder.fit_transform(df['smoker'])
df = pd.concat([df, encoded_smoker], axis=1)
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  smoker_0  smoker_1  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3         0         1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1         0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1         0
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0         1
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0         1
#
#      smoker_0  smoker_1  smoker_0  smoker_1
# 239         0         1         0         1
# 240         1         0         1         0
# 241         1         0         1         0
# 242         0         1         0         1
# 243         0         1         0         1

# %% [markdown]
# # 5. Using pandas' get_dummies function

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=['embark_town'] , dtype=int)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck alive  alone  embark_town_Cherbourg  \
# 0    man        True  NaN    no  False                      0
# 1  woman       False    C   yes  False                      1
# 2  woman       False  NaN   yes   True                      0
# 3  woman       False    C   yes  False                      0
# 4    man        True  NaN    no   True                      0
#
#    embark_town_Queenstown  embark_town_Southampton
# 0                       0                        1
# 1                       0                        0
# 2                       0                        1
# 3                       0                        1
# 4                       0                        1

# %% [markdown]
# # 6. Manual Encoding

# %%
# manual encoding using pandas
df = sns.load_dataset('tips')
df['day_encoded'] = df['day'].map({'Thur': 0, 'Fri': 1, 'Sat': 2, 'Sun': 3})
df
# Out:
#      total_bill   tip     sex smoker   day    time  size day_encoded
# 0         16.99  1.01  Female     No   Sun  Dinner     2           3
# 1         10.34  1.66    Male     No   Sun  Dinner     3           3
# 2         21.01  3.50    Male     No   Sun  Dinner     3           3
# 3         23.68  3.31    Male     No   Sun  Dinner     2           3
# 4         24.59  3.61  Female     No   Sun  Dinner     4           3
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3           2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2           2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           2
# 242       17.82  1.75    Male     No   Sat  Dinner     2           2
# 243       18.78  3.00  Female     No  Thur  Dinner     2           0
#
# [244 rows x 8 columns]
